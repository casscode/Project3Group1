# %%
import requests

url = "https://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCaseList"
params = {
    "states": "1,51",
    "fromYear": "2021",
    "toYear": "2022",
    "minNumOfVehicles": "1",
    "maxNumOfVehicles": "6",
    "format": "json"
}

response = requests.get(url, params=params)
data = response.json()

# %%
print(data)
# Out:
# {'Count': 1789, 'Message': 'Results returned successfully', 'Results': [[{'CountyName': 'ST. CLAIR (115)', 'CrashDate': '/Date(1613185800000-0500)/', 'Fatals': 2, 'Peds': 0, 'Persons': 3, 'St_Case': 10001, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 2}, {'CountyName': 'JEFFERSON (73)', 'CrashDate': '/Date(1613084400000-0500)/', 'Fatals': 2, 'Peds': 0, 'Persons': 2, 'St_Case': 10002, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'JEFFERSON (73)', 'CrashDate': '/Date(1612675200000-0500)/', 'Fatals': 1, 'Peds': 1, 'Persons': 1, 'St_Case': 10003, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'SHELBY (117)', 'CrashDate': '/Date(1612387200000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 1, 'St_Case': 10004, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'JEFFERSON (73)', 'CrashDate': '/Date(1612063200000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 4, 'St_Case': 10005, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 2}, {'CountyName': 'AUTAUGA (1)', 'CrashDate': '/Date(1611854100000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 3, 'St_Case': 10006, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 3}, {'CountyName': 'LIMESTONE (83)', 'CrashDate': '/Date(1611804300000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 1, 'St_Case': 10007, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'TUSCALOOSA (125)', 'CrashDate': '/Date(1611387840000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 2, 'St_Case': 10008, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 2}, {'CountyName': 'MONTGOMERY (101)', 'CrashDate': '/Date(1610861520000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 2, 'St_Case': 10009, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'JEFFERSON (73)', 'CrashDate': '/Date(1611118860000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 3, 'St_Case': 10010, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 3}, {'CountyName': 'JEFFERSON (73)', 'CrashDate': '/Date(1610735100000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 3, 'St_Case': 10011, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 2}, {'CountyName': 'CULLMAN (43)', 'CrashDate': '/Date(1610671500000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 4, 'St_Case': 10012, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 2}, {'CountyName': 'MOBILE (97)', 'CrashDate': '/Date(1609497360000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 2, 'St_Case': 10013, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 2}, {'CountyName': 'COFFEE (31)', 'CrashDate': '/Date(1609481280000-0500)/', 'Fatals': 1, 'Peds': 1, 'Persons': 2, 'St_Case': 10014, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'JEFFERSON (73)', 'CrashDate': '/Date(1609484580000-0500)/', 'Fatals': 1, 'Peds': 1, 'Persons': 1, 'St_Case': 10015, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'JEFFERSON (73)', 'CrashDate': '/Date(1609484940000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 1, 'St_Case': 10016, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'LIMESTONE (83)', 'CrashDate': '/Date(1609482600000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 1, 'St_Case': 10017, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'CALHOUN (15)', 'CrashDate': '/Date(1609545000000-0500)/', 'Fatals': 1, 'Peds': 1, 'Persons': 2, 'St_Case': 10018, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'FAYETTE (57)', 'CrashDate': '/Date(1609545600000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 1, 'St_Case': 10019, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'TUSCALOOSA (125)', 'CrashDate': '/Date(1609679940000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 1, 'St_Case': 10020, 'State': 1, 'StateName': 'Alabama', 'TotalVehicles': 1}, {'CountyName': 'JEFFERSON (73)', 'CrashDate': '/Date(1609783740000-0500)/', 'Fatals': 1, 'Peds': 0, 'Persons': 1, 'St_Case': 10021, 'State': 1, 'StateName':  ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 JSON.parse("Fatals")
#
# NameError: name 'JSON' is not defined
