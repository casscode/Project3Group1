# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
browser = Browser('chrome')

# %%
url = 'https://www.planecrashinfo.com/database.htm'
browser.visit(url)

# %%
df = pd.DataFrame(columns=['date', 'time', 'location','operator','aboard','fatalities'])
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
year_list = browser.links.find_by_partial_href('/')
year = 1920
for x in range(year,2023):
    url_text = 'https://www.planecrashinfo.com/'+str(x)+'/'+str(x)+'.htm'
    print(url_text)
    browser.visit(url_text)
    event_list = browser.links.find_by_partial_href('-')
    for event in event_list:
        event.click()
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        date = soup.find("td", string="Date:").find_next('td').text
        time = soup.find("td", string="Time:").find_next('td').text
        location = soup.find("td", string="Location:").find_next('td').text
        operator = soup.find("td", string="Operator:").find_next('td').text
        aboard_temp = soup.find("td", string="Aboard:").find_next('td').text
        aboard = aboard_temp.split(' ',1)[0]
        fatalities_temp = soup.find("td", string="Fatalities:").find_next('td').text
        fatalities = fatalities_temp.split(' ',1)[0]
        new_row = {'date':date,'time':time,'location':location,'operator':operator,'aboard':aboard,'fatalities':fatalities}
        print(new_row)
        new_row_df = pd.DataFrame([new_row])
        df = pd.concat([df, new_row_df])
        browser.back()
# Out:
# https://www.planecrashinfo.com/1920/1920.htm
# {'date': 'September 17, 1908', 'time': '1718', 'location': 'Fort Myer, Virginia', 'operator': 'Military - U.S. Army', 'aboard': '2', 'fatalities': '1'}
# {'date': 'September 07, 1909', 'time': '?', 'location': 'Juvisy-sur-Orge, France', 'operator': '?', 'aboard': '1', 'fatalities': '1'}
# {'date': 'July 12, 1912', 'time': '0630', 'location': 'Atlantic City, New Jersey', 'operator': 'Military - U.S. Navy', 'aboard': '5', 'fatalities': '5'}
# {'date': 'August 06, 1913', 'time': '?', 'location': 'Victoria, British Columbia, Canada', 'operator': 'Private', 'aboard': '1', 'fatalities': '1'}
# {'date': 'September 09, 1913', 'time': ' 1830', 'location': 'Over the North Sea', 'operator': 'Military - German Navy', 'aboard': '20', 'fatalities': '14'}
# {'date': 'October 17, 1913', 'time': '1030', 'location': 'Near Johannisthal, Germany', 'operator': 'Military - German Navy', 'aboard': '28', 'fatalities': '28'}
# {'date': 'March 05, 1915', 'time': '0100', 'location': 'Tienen, Belgium', 'operator': 'Military - German Navy', 'aboard': '41', 'fatalities': '17'}
# {'date': 'September 03, 1915', 'time': '1520', 'location': 'Off Cuxhaven, Germany', 'operator': 'Military - German Navy', 'aboard': '19', 'fatalities': '19'}
# {'date': 'July 28, 1916', 'time': '?', 'location': 'Near Jambol, Bulgeria', 'operator': 'Military - German Army', 'aboard': '20', 'fatalities': '20'}
# {'date': 'September 24, 1916', 'time': ' 0100', 'location': 'Billericay, England', 'operator': 'Military - German Navy', 'aboard': '22', 'fatalities': '22'}
# {'date': 'October 01, 1916', 'time': '2345', 'location': 'Potters Bar, England', 'operator': 'Military - German Navy', 'aboard': '19', 'fatalities': '19'}
# {'date': 'November 21, 1916', 'time': '?', 'location': 'Mainz, Germany', 'operator': 'Military - German Army', 'aboard': '28', 'fatalities': '27'}
# {'date': 'November 28, 1916', 'time': ' 2345', 'location': 'Off West Hartlepool, England', 'operator': 'Military - German Navy', 'aboard': '20', 'fatalities': '20'}
 'operator': 'US Aerial Mail Service', 'aboard': '1', 'fatalities': '1'}
# {'date': 'July 20, 1920', 'time': '?', 'location': 'Cartagena, Columbia', 'operator': 'Compañia Colombiana de Navegación Aérea', 'aboard': '1', 'fatalities': '1'}
# {'date': 'August 16, 1920', 'time': '?', 'location': 'Bedford, England', 'operator': 'By Air', 'aboard': '1', 'fatalities': '1'}
# {'date': 'August 16, 1920', 'time': '?', 'location': 'College Park, Maryland', 'operator': 'US Aerial Mail Service', 'aboard': '1', 'fatalities': '1'}
# {'date': 'September 01, 1920', 'time': '?', 'location': 'Morristown, New Jersey', 'operator': 'US Aerial Mail Service', 'aboard': '2', 'fatalities': '2'}
# {'date': 'September 15, 1920', 'time': '?', 'location': 'Pemberville, Ohio', 'operator': 'US Aerial Mail Service', 'aboard': '2', 'fatalities': '2'}
# {'date': 'September 27, 1920', 'time': '?', 'location': 'Hillersburg, Pennsylvania', 'operator': 'US Aerial Mail Service', 'aboard': '1', 'fatalities': '1'}
# {'date': 'October 02, 1920', 'time': '?', 'location': 'Off Port Vendres, France', 'operator': 'Latecoere Airlines', 'aboard': '2', 'fatalities': '2'}
# {'date': 'October 05, 1920', 'time': '?', 'location': 'Valencia, Spain', 'operator': 'Latecoere Airlines', 'aboard': '2', 'fatalities': '2'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 15
#      13 html = browser.html
#      14 soup = BeautifulSoup(html, 'html.parser')
# ---> 15 date = soup.find("td", string="Date:").find_next('td').text
#      16 time = soup.find("td", string="Time:").find_next('td').text
#      17 location = soup.find("td", string="Location:").find_next('td').text
#
# AttributeError: 'NoneType' object has no attribute 'find_next'

# %%
df
# Out:
#                  date   time                             location  \
# 0  September 17, 1908   1718                  Fort Myer, Virginia
# 0  September 07, 1909      ?              Juvisy-sur-Orge, France
# 0       July 12, 1912   0630            Atlantic City, New Jersey
# 0     August 06, 1913      ?   Victoria, British Columbia, Canada
# 0  September 09, 1913   1830                   Over the North Sea
# 0    October 17, 1913   1030           Near Johannisthal, Germany
# 0      March 05, 1915   0100                      Tienen, Belgium
# 0  September 03, 1915   1520                Off Cuxhaven, Germany
# 0       July 28, 1916      ?                Near Jambol, Bulgeria
# 0  September 24, 1916   0100                  Billericay, England
# 0    October 01, 1916   2345                 Potters Bar, England
# 0   November 21, 1916      ?                       Mainz, Germany
# 0   November 28, 1916   2345         Off West Hartlepool, England
# 0      March 04, 1917      ?                   Near Gent, Belgium
# 0      March 30, 1917      ?                 Off Northern Germany
# 0        May 14, 1917   0515         Near Texel Island, North Sea
# 0       June 14, 1917   0845       Off Vlieland Island, North Sea
# 0       June 17, 1917      ?               Near Yarmouth, England
# 0     August 21, 1917   0700                  Off western Denmark
# 0    October 20, 1917   0745               Near Luneville, France
# 0      April 07, 1918   2130               Over the Mediterranean
# 0     August 05, 1918      ?        Off Helgoland Island, Germany
# 0     August 11, 1918   1000            Ameland Island, North Sea
# 0   December 16, 1918      ?                Elizabeth, New Jersey
# 0        May 25, 1919      ?                      Cleveland, Ohio
# 0       July 19, 1919      ?                Dix Run, Pennsylvania
# 0       July 21, 1919   1655                    Chicago, Illinois
# 0     August 02, 1919      ?                        Verona, Italy
# 0    October 02, 1919      ?                   Newcastle, England
# 0    October 14, 1919      ?               Cantonsville, Maryland
# 0    October 20, 1919      ?  English Channel off Forkstone, Kent
# 0    October 30, 1919      ?              Long Valley, New Jersey
# 0   December 11, 1919      ?                Catherham, Surrey, UK
# 0      March 10, 1920      ?                   New Paris, Indiana
# 0      March 30, 1920      ?                   Newark, New Jersey
# 0      April 10, 1920      ?                   Newark, New Jersey
# 0      April 11, 1920      ?             Heller Field, New Jersey
# 0        May 12, 1920      ?                      Oskaloosa, Iowa
# 0       June 06, 1920      ?                      Cleveland, Ohio
# 0       July 20, 1920      ?                  Cartagena, Columbia
# 0     August 16, 1920      ?                     Bedford, England
# 0     August 16, 1920      ?               College Park, Maryland
# 0  September 01, 1920      ?               Morristown, New Jersey
# 0  September 15, 1920      ?                    Pemberville, Ohio
# 0  September 27, 1920      ?            Hillersburg, Pennsylvania
# 0    October 02, 1920      ?             Off Port Vendres, France
# 0    October 05, 1920      ?                      Valencia, Spain
#
#                                   operator aboard fatalities
# 0                     Military - U.S. Army      2          1
# 0                                        ?      1          1
# 0                     Military - U.S. Navy      5          5
# 0                                  Private      1          1
# 0                   Military - German Navy     20         14
# 0                   Military - German Navy     28         28
# 0                   Military - German Navy     41         17
# 0                   Military - German Navy     19         19
# 0                   Military - German Army     20         20
# 0                   Military - German Navy     22         22
# 0                   Military - German Navy     19         19
# 0                   Military - German Army     28         27
# 0                   Military - German Navy     20         20
# 0                   Military - German Army     20         20
# 0                   Military - German Navy     23         23
# 0                   Military - German Navy     21         21
# 0                   Military - German Navy     24         24
# 0                                        ?     16         14
# 0                   Military - German Navy     18         18
# 0                   Military - German Navy     18         18
# 0                   Military - German Navy     23         23
# 0                   Military - German Navy     22         22
# 0                   Military - German Navy     19         19
# 0                   US Aerial Mail Service      1          1
# 0                   US Aerial Mail Service      1          1
# 0                   US Aerial Mail Service      1          1
# 0       Wingfoot Air Express Goodyear Tire      ?          3
# 0                          Caproni Company     14         14
# 0            Aircraft Transport and Travel      1          1
# 0                   US Aerial Mail Service      1          1
# 0            Aircraft Transport and Travel      0          0
# 0                   US Aerial Mail Service      1          1
# 0                Aircraft Travel Transport      1          1
# 0                   US Aerial Mail Service      1          1
# 0                   US Aerial Mail Service      1          1
# 0                   US Aerial Mail Service      2          1
# 0                   US Aerial Mail Service      2          1
# 0                   US Aerial Mail Service      2          1
# 0                   US Aerial Mail Service      1          1
# 0  Compañia Colombiana de Navegación Aérea      1          1
# 0                                   By Air      1          1
# 0                   US Aerial Mail Service      1          1
# 0                   US Aerial Mail Service      2          2
# 0                   US Aerial Mail Service      2          2
# 0                   US Aerial Mail Service      1          1
# 0                       Latecoere Airlines      2          2
# 0                       Latecoere Airlines      2          2

# %%
from geopy.geocoders import Nominatim

# %%
df['location'].astype(str)
df.dtypes

# %%
geolocator = Nominatim(timeout=10, user_agent = "jimmy")
location = geolocator.geocode('Fort Myer, Virginia')
print(location)
print((location.latitude, location.longitude))

# %%
lat = np.array([])
lon = np.array([])
for location, row in df.iterrows():
    geolocator = Nominatim(timeout=10, user_agent = "jimmy")
    location = geolocator.geocode(row['location'])
    print(location)
#     lats = np.append(lat, location.latitude)
#     lons = np.append(lon, location.longitude)

# %%
df['latitude']= lats
df['longitude'] = lons

# %% [markdown]
# df.to_csv(plane_crash_data, encoding='utf-8', index=False)
